# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import stats

# %%
# Load the dataset
churn_df_EDA = pd.read_csv('churn_df_for_EDA.csv', index_col=0)

# %%
churn_df_EDA.Attrition_Flag.value_counts(normalize=True)
# Out:
# Existing Customer    0.839427
# Attrited Customer    0.160573
# Name: Attrition_Flag, dtype: float64

# %%
churn_df_EDA.corr()
# Out:
#                           Client_ID       Age  Dependent_Count  \
# Client_ID                  1.000000  0.007617         0.006022
# Age                        0.007617  1.000000        -0.121745
# Dependent_Count            0.006022 -0.121745         1.000000
# Months_On_Book             0.134729  0.789116        -0.103275
# Total_Relationship_Count   0.006787 -0.010679        -0.039874
# Months_Inactive            0.005912  0.054679        -0.010336
# Contacts_Count             0.006423 -0.018612        -0.040742
# Credit_Limit               0.005440  0.002901         0.067096
# Total_Revolving_Bal        0.000491  0.014665        -0.002601
# Avg_Open_To_Buy            0.005395  0.001585         0.067314
# Total_Amt_Chng_Q4_Q1       0.018587 -0.060748        -0.038376
# Total_Trans_Amt           -0.020142 -0.047112         0.025738
# Total_Trans_Ct            -0.003240 -0.067594         0.050801
# Total_Ct_Chng_Q4_Q1        0.008096 -0.011792         0.010377
# ...

# %%
plt.figure(figsize=(40,20))
sns.heatmap(churn_df_EDA.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
churn_df_EDA.hist(bins=30, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Client_ID'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Dependent_Count'}>,
#         <AxesSubplot:title={'center':'Months_On_Book'}>],
#        [<AxesSubplot:title={'center':'Total_Relationship_Count'}>,
#         <AxesSubplot:title={'center':'Months_Inactive'}>,
#         <AxesSubplot:title={'center':'Contacts_Count'}>,
#         <AxesSubplot:title={'center':'Credit_Limit'}>],
#        [<AxesSubplot:title={'center':'Total_Revolving_Bal'}>,
#         <AxesSubplot:title={'center':'Avg_Open_To_Buy'}>,
#         <AxesSubplot:title={'center':'Total_Amt_Chng_Q4_Q1'}>,
#         <AxesSubplot:title={'center':'Total_Trans_Amt'}>],
#        [<AxesSubplot:title={'center':'Total_Trans_Ct'}>,
#         <AxesSubplot:title={'center':'Total_Ct_Chng_Q4_Q1'}>,
#         <AxesSubplot:title={'center':'Avg_Utilization_Ratio'}>,
#         <AxesSubplot:>]], dtype=object)
