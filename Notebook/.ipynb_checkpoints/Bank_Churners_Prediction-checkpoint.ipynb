# %% [markdown]
# # Capstone Project Two (Data Wrangling)

# %% [markdown]
# ## 1. Importing libraries and load the data

# %%
# Importing all required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import os
from scipy import stats

# %%
# Load the data
original_df = pd.read_csv("BankChurnersModified.csv")
churn_df = original_df.copy()
churn_df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M              3.0
# 1  818770008  Existing Customer            49      F              5.0
# 2  713982108  Existing Customer            51      M              3.0
# 3  769911858  Existing Customer            40      F              4.0
# 4  709106358  Existing Customer            40      M              3.0
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 2. Removing unnecessary columns and rename

# %%
# Delete unnecessary columns
churn_df = churn_df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
       'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1)

# %%
# Rename some columns
old_names = churn_df.columns
new_names = ['Client_ID', 'Attrition_Flag', 'Age', 'Gender', 
        'Dependent_Count', 'Education', 'Marital_Status',
       'Income', 'Card_Category', 'Months_On_Book',
       'Total_Relationship_Count', 'Months_Inactive',
       'Contacts_Count', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']
churn_df.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %% [markdown]
# ## 3. Explore the dataset

# %%
churn_df.columns
# Out:
# Index(['Client_ID', 'Attrition_Flag', 'Age', 'Gender', 'Dependent_Count',
#        'Education', 'Marital_Status', 'Income', 'Card_Category',
#        'Months_On_Book', 'Total_Relationship_Count', 'Months_Inactive',
#        'Contacts_Count', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
churn_df.shape
# Out:
# (10135, 21)

# %%
churn_df.index
# Out:
# RangeIndex(start=0, stop=10135, step=1)

# %%
# Check the dtypes
churn_df.dtypes
# Out:
# Client_ID                     int64
# Attrition_Flag               object
# Age                           int64
# Gender                       object
# Dependent_Count             float64
# Education                    object
# Marital_Status               object
# Income                       object
# Card_Category                object
# Months_On_Book                int64
# Total_Relationship_Count      int64
# Months_Inactive               int64
# Contacts_Count                int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
# data type plot
churn_df.dtypes.value_counts().plot.pie(explode=[0.05,0.05,0.05],autopct='%1.1f%%',shadow=True)
plt.title('Percent Data Types');

# %%
# cross check the datatype of 'Age' column
# churn_df['Age'].min()
# churn_df['Age'].max()
churn_df['Age'].mean()
# Out:
# 46.32836704489393

# %% [markdown]
# ## 4. Explore the summary statistics

# %%
# Get the summary of the data
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10135 entries, 0 to 10134
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client_ID                 10135 non-null  int64
#  1   Attrition_Flag            10135 non-null  object
#  2   Age                       10135 non-null  int64
#  3   Gender                    10135 non-null  object
#  4   Dependent_Count           10125 non-null  float64
#  5   Education                 10135 non-null  object
#  6   Marital_Status            10135 non-null  object
#  7   Income                    10135 non-null  object
#  8   Card_Category             10135 non-null  object
#  9   Months_On_Book            10135 non-null  int64
#  10  Total_Relationship_Count  10135 non-null  int64
#  11  Months_Inactive           10135 non-null  int64
#  12  Contacts_Count            10135 non-null  int64
#  13  Credit_Limit              10135 non-null  float64
#  14  Total_Revolving_Bal       10135 non-null  int64
#  15  Avg_Open_To_Buy           10135 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10135 non-null  float64
#  17  Total_Trans_Amt           10135 non-null  int64
#  18  Total_Trans_Ct            10135 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1       10135 non-null  float64
#  20  Avg_Utilization_Ratio     10135 non-null  float64
# dtypes: float64(6), int64(9), object(6)
# memory usage: 1.6+ MB

# %%
churn_df.describe(include='all')
# Out:
#            Client_ID     Attrition_Flag           Age Gender  Dependent_Count  \
# count   1.013500e+04              10135  10135.000000  10135     10125.000000
# unique           NaN                  2           NaN      3              NaN
# top              NaN  Existing Customer           NaN      F              NaN
# freq             NaN               8507           NaN   5359              NaN
# mean    7.391926e+08                NaN     46.328367    NaN         2.346272
# std     3.690879e+07                NaN      8.018710    NaN         1.298875
# min     7.080821e+08                NaN     26.000000    NaN         0.000000
# 25%     7.130368e+08                NaN     41.000000    NaN         1.000000
# 50%     7.179283e+08                NaN     46.000000    NaN         2.000000
# 75%     7.731640e+08                NaN     52.000000    NaN         3.000000
# max     8.283431e+08                NaN     73.000000    NaN         5.000000
#
#        Education Marital_Status          Income Card_Category  Months_On_Book  \
# count      10135          10135           10135         10135    10135.000000
# unique         7              4               6             4             NaN
# top     Graduate        Married  Less than $40K          Blue             NaN
# freq        3132           4693            3561          9443             NaN
# mean         NaN            NaN             NaN           NaN       35.929650
# std          NaN            NaN             NaN           NaN        7.988773
# min          NaN            NaN             NaN           NaN       13.000000
# 25%          NaN            NaN             NaN           NaN       31.000000
# 50%          NaN            NaN             NaN           NaN       36.000000
# 75%          NaN            NaN             NaN           NaN       40.000000
# max          NaN            NaN             NaN           NaN       56.000000
#
#         ...  Months_Inactive  Contacts_Count  Credit_Limit  \
# count   ...     10135.000000    10135.000000  10135.000000
# unique  ...              NaN             NaN           NaN
# top     ...              NaN             NaN           NaN
# freq    ...              NaN             NaN           NaN
# mean    ...         2.341095        2.456043   8630.591130
# std     ...         1.010886        1.106263   9090.843559
# min     ...         0.000000        0.000000      0.000000
# 25%     ...         2.000000        2.000000   2551.500000
# 50%     ...         2.000000        2.000000   4549.000000
# 75%     ...         3.000000        3.000000  11067.500000
# max     ...         6.000000        6.000000  34516.000000
#
#         Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# count          10135.000000     10135.000000          10135.000000
# unique                  NaN              NaN                   NaN
# top                     NaN              NaN                   NaN
# freq                    NaN              NaN                   NaN
# mean            1162.955895      7471.360839              0.759939
# std              814.752460      9091.545474              0.219286
# min                0.000000         3.000000              0.000000
# 25%              379.500000      1324.500000              0.631000
# 50%             1276.000000      3475.000000              0.736000
# 75%             1783.500000      9862.500000              0.859000
# max             2517.000000     34516.000000              3.397000
#
#         Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# count      10135.000000    10135.000000         10135.000000
# unique              NaN             NaN                  NaN
# top                 NaN             NaN                  NaN
# freq                NaN             NaN                  NaN
# mean        4401.719783       64.838185             0.712271
# std         3396.844245       23.475522             0.238256
# min          510.000000       10.000000             0.000000
# 25%         2153.000000       45.000000             0.581000
# 50%         3897.000000       67.000000             0.702000
# 75%         4740.000000       81.000000             0.818000
# max        18484.000000      139.000000             3.714000
#
#         Avg_Utilization_Ratio
# count            10135.000000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean                 0.274889
# std                  0.275684
# min                  0.000000
# 25%                  0.023000
# 50%                  0.175000
# 75%                  0.503000
# max                  0.999000
#
# [11 rows x 21 columns]

# %%
# profile = ProfileReport(churn_df, explorative=True)
# profile

# %% [markdown]
# ## 5. Finding missing and duplicated values and irregularities

# %%
# churn_df.isna()
# churn_df.isna().any()
churn_df.isnull().sum()
# Out:
# Client_ID                    0
# Attrition_Flag               0
# Age                          0
# Gender                       0
# Dependent_Count             10
# Education                    0
# Marital_Status               0
# Income                       0
# Card_Category                0
# Months_On_Book               0
# Total_Relationship_Count     0
# Months_Inactive              0
# Contacts_Count               0
# Credit_Limit                 0
# Total_Revolving_Bal          0
# Avg_Open_To_Buy              0
# Total_Amt_Chng_Q4_Q1         0
# Total_Trans_Amt              0
# Total_Trans_Ct               0
# Total_Ct_Chng_Q4_Q1          0
# Avg_Utilization_Ratio        0
# dtype: int64

# %%
churn_df['Dependent_Count'].fillna(churn_df['Dependent_Count'].median(), inplace=True)
churn_df.isnull().sum()
# Out:
# Client_ID                   0
# Attrition_Flag              0
# Age                         0
# Gender                      0
# Dependent_Count             0
# Education                   0
# Marital_Status              0
# Income                      0
# Card_Category               0
# Months_On_Book              0
# Total_Relationship_Count    0
# Months_Inactive             0
# Contacts_Count              0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# check out the duplicated columns
# duplicates = churn_df.duplicated()
# print(duplicates.sum())
churn_df[churn_df.duplicated(['Client_ID'])]
# Out:
#        Client_ID     Attrition_Flag  Age Gender  Dependent_Count    Education  \
# 10127  768805383  Existing Customer   45      M              3.0  High School
# 10128  779480658  Existing Customer   58      F              4.0     Graduate
# 10129  711498258  Existing Customer   54      M              3.0  High School
# 10130  709316433  Existing Customer   52      M              2.0  High School
# 10131  778734108  Existing Customer   36      M              3.0   Uneducated
# 10132  778388358  Attrited Customer   56      M              3.0     Graduate
# 10133  716773533  Existing Customer   33      M              3.0     Graduate
# 10134  822130683  Existing Customer   61      M              0.0     Graduate
#
#       Marital_Status        Income Card_Category  Months_On_Book  ...  \
# 10127        Married   $60K - $80K          Blue              39  ...
# 10128        Married       Unknown          Blue              42  ...
# 10129        Married       $120K +          Blue              42  ...
# 10130         Single   $60K - $80K        Silver              33  ...
# 10131        Married   $60K - $80K          Blue              16  ...
# 10132         Single   $60K - $80K          Blue              36  ...
# 10133        Married   $60K - $80K          Blue              36  ...
# 10134        Married  $80K - $120K          Blue              56  ...
#
#        Months_Inactive  Contacts_Count  Credit_Limit  Total_Revolving_Bal  \
# 10127                1               3       12691.0                  777
# 10128                3               4       10247.0                 1600
# 10129                3               2           0.0                 1655
# 10130                1               4       33182.0                 1997
# 10131                5               4           0.0                 1252
# 10132                2               3        4742.0                  855
# 10133                1               3        1726.0                 1215
# 10134                2               4        8420.0                 1389
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 10127          11914.0                 1.335             1144              42
# 10128           8647.0                 0.630             1754              44
# 10129          18656.0                 0.431             1266              34
# 10130          31185.0                 0.755             1630              43
# 10131            434.0                 0.575             1758              42
# 10132           3887.0                 0.635              870              24
# 10133            511.0                 1.175             1712              48
# 10134           7031.0                 0.522             1114              34
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 10127                1.625                  0.061
# 10128                0.692                  0.156
# 10129                0.308                  0.081
# 10130                0.870                  0.060
# 10131                1.100                  0.743
# 10132                0.500                  0.180
# 10133                0.548                  0.704
# 10134                0.545                  0.165
#
# [8 rows x 21 columns]

# %% [markdown]
# ### 1. Drop duplicated values

# %%
# Drop duplicate row
churn_df.drop_duplicates(inplace=True)
print(churn_df[churn_df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Client_ID, Attrition_Flag, Age, Gender, Dependent_Count, Education, Marital_Status, Income, Card_Category, Months_On_Book, Total_Relationship_Count, Months_Inactive, Contacts_Count, Credit_Limit, Total_Revolving_Bal, Avg_Open_To_Buy, Total_Amt_Chng_Q4_Q1, Total_Trans_Amt, Total_Trans_Ct, Total_Ct_Chng_Q4_Q1, Avg_Utilization_Ratio]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### 2. Finding and correcting irregularities of individual attributes

# %%
# df['gender'].value_counts(normalize=True) * 100
churn_df['Attrition_Flag'].value_counts(normalize=True) * 100
# Out:
# Existing Customer    83.93721
# Attrited Customer    16.06279
# Name: Attrition_Flag, dtype: float64

# %%
# Number of Unique values of our categorical columns
churn_df['Attrition_Flag'].value_counts().head()
# Out:
# Existing Customer    8502
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
churn_df['Gender'].value_counts().head()
# Out:
# F    5358
# M    4768
# U       3
# Name: Gender, dtype: int64

# %%
churn_df.loc[churn_df['Gender']=='U']
# Out:
#      Client_ID     Attrition_Flag  Age Gender  Dependent_Count   Education  \
# 8    710930508  Existing Customer   37      U              3.0  Uneducated
# 293  771742533  Existing Customer   48      U              2.0    Graduate
# 569  787623858  Existing Customer   43      U              2.0  Uneducated
#
#     Marital_Status       Income Card_Category  Months_On_Book  ...  \
# 8           Single  $60K - $80K          Blue              36  ...
# 293        Unknown  $40K - $60K          Blue              36  ...
# 569       Divorced      $120K +        Silver              24  ...
#
#      Months_Inactive  Contacts_Count  Credit_Limit  Total_Revolving_Bal  \
# 8                  2               0       22352.0                 2517
# 293                1               2       13068.0                 1718
# 569                2               0       34516.0                 1938
#
#      Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 8            19835.0                 3.355             1350              24
# 293          11350.0                 0.607              937              28
# 569          32578.0                 0.426             1215              45
#
#      Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 8                  1.182                  0.113
# 293                0.556                  0.131
# 569                0.406                  0.056
#
# [3 rows x 21 columns]

# %%
churn_df.shape
# Out:
# (10129, 21)

# %%
churn_df = churn_df.loc[churn_df['Gender']!='U']

# %%
churn_df.shape
# Out:
# (10126, 21)

# %%
# churn_df['Income'].nunique()
churn_df['Income'].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1789
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income, dtype: int64

# %%
# churn_df['Age'].unique()
# churn_df['Age'].nunique()
churn_df['Age'].value_counts().head()
# Out:
# 44    500
# 49    495
# 46    490
# 45    486
# 47    479
# Name: Age, dtype: int64

# %%
# churn_df['Marital_Status'].nunique()
# churn_df['Marital_Status'].unique()
churn_df['Marital_Status'].value_counts().head()
# Out:
# Married     4689
# Single      3942
# Unknown      748
# Divorced     747
# Name: Marital_Status, dtype: int64

# %%
churn_df.groupby('Marital_Status').count()
# Out:
#                 Client_ID  Attrition_Flag   Age  Gender  Dependent_Count  \
# Marital_Status
# Divorced              747             747   747     747              747
# Married              4689            4689  4689    4689             4689
# Single               3942            3942  3942    3942             3942
# Unknown               748             748   748     748              748
#
#                 Education  Income  Card_Category  Months_On_Book  \
# Marital_Status
# Divorced              747     747            747             747
# Married              4689    4689           4689            4689
# Single               3942    3942           3942            3942
# Unknown               748     748            748             748
#
#                 Total_Relationship_Count  Months_Inactive  Contacts_Count  \
# Marital_Status
# Divorced                             747              747             747
# Married                             4689             4689            4689
# Single                              3942             3942            3942
# Unknown                              748              748             748
#
#                 Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# Marital_Status
# Divorced                 747                  747              747
# Married                 4689                 4689             4689
# Single                  3942                 3942             3942
# Unknown                  748                  748              748
#
#                 Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# Marital_Status
# Divorced                         747              747             747
# Married                         4689             4689            4689
# Single                          3942             3942            3942
# Unknown                          748              748             748
#
#                 Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# Marital_Status
# Divorced                        747                    747
# Married                        4689                   4689
# Single                         3942                   3942
# Unknown                         748                    748

# %%
# churn_df['Education'].unique()
# churn_df['Education'].nunique()
churn_df['Education'].value_counts().head()
churn_df['Education'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
# Inspecting specific countries data
churn_df[churn_df['Attrition_Flag']=='Attrited Customer']
# Out:
#        Client_ID     Attrition_Flag  Age Gender  Dependent_Count    Education  \
# 21     708508758  Attrited Customer   62      F              0.0     Graduate
# 39     708300483  Attrited Customer   66      F              0.0    Doctorate
# 51     779471883  Attrited Customer   54      F              1.0     Graduate
# 54     714374133  Attrited Customer   56      M              2.0     Graduate
# 61     712030833  Attrited Customer   48      M              2.0     Graduate
# ...          ...                ...  ...    ...              ...          ...
# 10119  716893683  Attrited Customer   55      F              3.0   Uneducated
# 10123  710638233  Attrited Customer   41      M              2.0      Unknown
# 10124  716506083  Attrited Customer   44      F              1.0  High School
# 10125  717406983  Attrited Customer   30      M              2.0     Graduate
# 10126  714337233  Attrited Customer   43      F              2.0     Graduate
#
#       Marital_Status          Income Card_Category  Months_On_Book  ...  \
# 21           Married  Less than $40K          Blue              49  ...
# 39           Married         Unknown          Blue              56  ...
# 51           Married  Less than $40K          Blue              40  ...
# 54           Married         $120K +          Blue              36  ...
# 61           Married     $60K - $80K        Silver              35  ...
# ...              ...             ...           ...             ...  ...
# 10119         Single         Unknown          Blue              47  ...
# 10123       Divorced     $40K - $60K          Blue              25  ...
# 10124        Married  Less than $40K          Blue              36  ...
# 10125        Unknown     $40K - $60K          Blue              36  ...
# 10126        Married  Less than $40K        Silver              25  ...
#
#        Months_Inactive  Contacts_Count  Credit_Limit  Total_Revolving_Bal  \
# 21                   3               3        1438.3                    0
# 39                   4               3        7882.0                  605
# 51                   3               1        1438.3                  808
# 54                   3               3       15769.0                    0
# 61                   4               4       34516.0                    0
# ...                ...             ...           ...                  ...
# 10119                3               3       14657.0                 2517
# 10123                2               3        4277.0                 2186
# 10124                3               4        5409.0                    0
# 10125                3               3        5281.0                    0
# 10126                2               4       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 21              1438.3                 1.047              692              16
# 39              7277.0                 1.052              704              16
# 51               630.3                 0.997              705              19
# 54             15769.0                 1.041              602              15
# 61             34516.0                 0.763              691              15
# ...                ...                   ...              ...             ...
# 10119          12140.0                 0.166             6009              53
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 21                   0.600                  0.000
# 39                   0.143                  0.077
# 51                   0.900                  0.562
# 54                   0.364                  0.000
# 61                   0.500                  0.000
# ...                    ...                    ...
# 10119                0.514                  0.172
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [1627 rows x 21 columns]

# %%
# Finding no. of irrelevant credit limits of 0 dollar
churn_df.loc[churn_df['Credit_Limit']<500, 'Credit_Limit'].value_counts()
# Out:
# 0.0    6
# Name: Credit_Limit, dtype: int64

# %%
# Finding irrelevant rows of credit limits of 0 dollar
churn_df.loc[churn_df['Credit_Limit']<500, 'Credit_Limit']
# Out:
# 9149     0.0
# 9320     0.0
# 9492     0.0
# 9705     0.0
# 10129    0.0
# 10131    0.0
# Name: Credit_Limit, dtype: float64

# %%
churn_df.shape

# %%
# dropping particular rows containing 0 credit limit
churn_df = churn_df.loc[churn_df['Credit_Limit']>500]

# %%
churn_df.shape

# %%
churn_df.duplicated().sum()

# %% [markdown]
# ## 6. Finding numerical and categorical columns

# %%
# Check out the numerical columns
churn_df.select_dtypes(include=np.number)

# %%
# Check out the categorical columns
churn_df.select_dtypes('object')

# %% [markdown]
# ## 7. Visualizing correlations and outliers of individual columns

# %%
#Create two subplots on 1 row and 2 columns with a figsize of (12, 8)
fig, ax = plt.subplots(1, 2, figsize=(12,8))
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
churn_df.Attrition_Flag.value_counts().plot(kind='barh', ax=ax[0])
#Give the plot a helpful title of 'Region'
ax[0].set_title('Attrition Flag')
#Label the xaxis 'Count'
ax[0].set_xlabel('Count')
#Specify a horizontal barplot ('barh') as kind of plot (kind=)
churn_df.Education.value_counts().plot(kind='barh', ax=ax[1])
#Give the plot a helpful title of 'state'
ax[1].set_title('Education')
#Label the xaxis 'Count'
ax[1].set_xlabel('Count')
#Give the subplots a little "breathing room" with a wspace of 0.5
plt.subplots_adjust(wspace=0.5);
#You're encouraged to explore a few different figure sizes, orientations, and spacing here
# as the importance of easy-to-read and informative figures is frequently understated
# and you will find the ability to tweak figures invaluable later on

# %%
# Finding coorelation between Credit_Limit and Avg_Open_To_Buy columns
corr = churn_df[['Credit_Limit','Avg_Open_To_Buy']]
corr.plot(kind='scatter', x='Credit_Limit', y='Avg_Open_To_Buy')
plt.show()

# %% [markdown]
# I have found a positive coorelation between 'Credit_Limit' and 'Avg_Open_to_Buy' columns of our dataframe. Since the coorelation is universal and true, because, the more the credit limit the more amount balance the customer will have open to spend. This coorelation will not affect our exploration and modeling.

# %%
# filter the numeric columns from the dataframe
# churn_df.select_dtypes(include=np.number)
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
churn_df.select_dtypes(include=numerics)

# %%
# Checking Outliers for Credit_Limit column
churn_df.Credit_Limit.plot(kind='box')
plt.show()

# %%
# Checking Outliers for Age column
churn_df.Age.plot(kind='box')
plt.show()

# %%
# Checking Outliers for Total_trans_Amt column
churn_df.Total_Trans_Amt.plot(kind='box')
plt.show()

# %%
# churn_df.Credit_Limit.max()
churn_df.Credit_Limit.quantile(q=0.75)

# %%
churn_df['Credit_Limit'].plot(kind='hist',bins=20, rot=45, colormap='coolwarm',alpha=0.8)
plt.show()

# %%
# Discarding outliers from dataframe
"""
# z_scores = stats.zscore(df)
def drop_outliers(df, col_name):
    abs_z_scores = np.abs(stats.zscore(df[col_name]))
    filtered_entries = (abs_z_scores < 3)
    new_df = df[filtered_entries]
    return new_df
new_churn = drop_outliers(churn_df, 'Avg_Open_To_Buy')
new_churn.shape
"""
"""
# Drop all outliers from numerical columns
from scipy import stats

def drop_numerical_outliers(df1, z_thresh=3):
    # Constrains will contain `True` or `False` depending on if it is a value below the threshold.
    constrains = df1.select_dtypes(include=[np.number]) \
        .apply(lambda x: np.abs(stats.zscore(x)) < z_thresh) \
        .all(axis=1)
    # Drop (inplace) values set to be rejected
    df1.drop(df1.index[~constrains], inplace=True)
    return df1
final_df = drop_numerical_outliers(churn_df)
"""

# %%
#visualizing the features whigh positive and negative correlation
figure, axes = plt.subplots(nrows=3, ncols=3, figsize=(25,15))
figure.suptitle('Features With High Negative Correlation', size=35)
sns.boxplot(x="Attrition_Flag", y="Total_Relationship_Count", data=churn_df, ax=axes[0,0])
sns.boxplot(x="Attrition_Flag", y="Total_Revolving_Bal", data=churn_df, ax=axes[0,1])
sns.boxplot(x="Attrition_Flag", y="Total_Amt_Chng_Q4_Q1", data=churn_df, ax=axes[0,2])
sns.boxplot(x="Attrition_Flag", y="Total_Trans_Amt", data=churn_df, ax=axes[1,0])
sns.boxplot(x="Attrition_Flag", y="Total_Trans_Ct", data=churn_df, ax=axes[1,1])
sns.boxplot(x="Attrition_Flag", y="Total_Ct_Chng_Q4_Q1", data=churn_df, ax=axes[1,2])
sns.boxplot(x="Attrition_Flag", y="Avg_Utilization_Ratio", data=churn_df, ax=axes[2,0])
sns.boxplot(x="Attrition_Flag", y="Months_Inactive", data=churn_df, ax=axes[2,1])
sns.boxplot(x="Attrition_Flag", y="Contacts_Count", data=churn_df, ax=axes[2,2])

# %%
# Not Working
"""
my_df = pd.DataFrame()
for country in country_list:
    new_df= life_expectancy_data.loc[life_expectancy_data['Country']==country]
    my_df=pd.concat([my_df+new_df], ignore_index=True)
    """
"""
life_expectancy_data['GDP'].fillna(life_expectancy_data['GDP'].median(), inplace=True)
life_expectancy_data.loc[life_expectancy_data['Country']=='Bahamas','GDP']
"""

# %% [markdown]
# ## 8. Save data

# %%
# save the churn_df dataframe to drive.
churn_df.to_csv('churn_df_corrected.csv')

# %%
"""
# save the data to a new csv file
from sb_utils import save_file
datapath = "C:/Users/shaja/Desktop/Springboard Projects/DataScienceCapstoneProjectTwo/Dataset"
save_file(churn_df, 'churn_df_corrected.csv', datapath)
"""
"""
cwd = os.getcwd()
path = cwd + "/new"
df.to_csv(path)
"""
